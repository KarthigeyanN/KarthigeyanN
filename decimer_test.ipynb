# %% [markdown]
# <a href="https://colab.research.google.com/github/KarthigeyanN/KarthigeyanN/blob/main/decimer_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install decimer
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 kB 157.1 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.3/475.3 MB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 49.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 37.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 34.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 36.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 22.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 52.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 24.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 6.2 MB/s eta 0:00:00
# ...

# %%
from DECIMER import predict_SMILES
# Out:
# ...
# /root/.data/DECIMER-V2/models.zip
# ... done downloading trained model!
# ...
# /root/.data/DECIMER-V2/DECIMER_HandDrawn_model.zip
# ... done downloading trained model!

# %%
# prompt: !wget https://upload.wikimedia.org/wikipedia/commons/4/4c/Caffeine-2D-skeletal.png -o test.png

# !rm -rf test.png
# !wget https://upload.wikimedia.org/wikipedia/commons/4/4c/Caffeine-2D-skeletal.png -O test.png

image_path = "test.png"
SMILES = predict_SMILES(image_path)
SMILES
# Out:
# --2025-06-18 15:33:58--  https://upload.wikimedia.org/wikipedia/commons/4/4c/Caffeine-2D-skeletal.png
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 198.35.26.112, 2620:0:863:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|198.35.26.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 42283 (41K) [image/png]
# Saving to: ‘test.png’
#
# test.png            100%[===================>]  41.29K  --.-KB/s    in 0.02s
#
# 2025-06-18 15:33:58 (1.82 MB/s) - ‘test.png’ saved [42283/42283]
# 'CN1C=NC2=C1C(=O)N(C)C(=O)N2C'
